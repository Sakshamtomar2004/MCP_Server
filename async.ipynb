# %%
import asyncio

# %%
messages=[{
    "content":"Write an email"},
    {
        "AI_Mesaage:Hello"
    }
]

# %%
messages
# Out:
# [{'content': 'Write an email'}, {'AI_Mesaage:Hello'}]

# %%
messages = [{"content": 'Write an email'}, {"AL_Message": "Hello"}]

# Access the value directly
hello_text = messages[-1]["AL_Message"]

# %%
{
    "messages": [
        HumanMessage(...),  # Your input
        AIMessage(...),     # Model's initial response
        ToolMessage(...)    # Result from external tool
    ]
}
# Out:
#   Cell In[17], line 1
#     p:[{messages:[1,2,3],[9,0,8]}]
#                                ^
# SyntaxError: ':' expected after dictionary key

# %%
HumanMessage(
    content='Use BrightData to find...',  # Your prompt
    additional_kwargs={},                # Metadata
    id='89538b43...'                     # Unique ID
)

# %%
ToolMessage(
    content='who won... - Google Search...',  # Raw tool output
    name='search_engine',                    # Tool identifier
    tool_call_id='53ed1e57...'               # Links to AIMessage
)

# %%
tool_query = response['messages'][1].additional_kwargs['function_call']['arguments']
# Returns: {"query":"who won the most recent IPL tournament"}

# %%
from langchain_core.messages import AIMessage

# Sample AIMessage
ai_message = AIMessage(
    content="The winner of IPL 2023 was Chennai Super Kings",
    additional_kwargs={
        'function_call': {
            'name': 'search_engine',
            'arguments': '{"query":"IPL 2023 winner"}'
        }
    }
)

# Print just the content
print(ai_message.content)
# Output: The winner of IPL 2023 was Chennai Super Kings

# %%
pip install -U langchain-google-community[gmail] langchain langgraph google-api-python-client google-auth-oauthlib google-auth-httplib2
# Out:
# ...
#   Using cached google_api_python_client-2.177.0-py3-none-any.whl.metadata (7.0 kB)
# ...
#   Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached beautifulsoup4-4.13.4-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached langchain_community-0.3.27-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached uritemplate-4.2.0-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached soupsieve-2.7-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# ...
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# ...
#   Using cached numpy-2.3.2-cp311-cp311-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# ...
